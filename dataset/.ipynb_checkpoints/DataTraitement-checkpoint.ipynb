# %% [markdown]
# #  Traitements des données du geipan

# %% [markdown]
# ## 1/ Données cas_pub

# %%
## imports
import os
import re
import sys
import numpy as np
import pandas as pd

# %% [markdown]
# #### Import  dataset

# %%
df_cas = pd.read_csv('cas_pub.csv', sep =';', encoding='iso-8859-1')
df_cas.head()
# Out:
#    id_cas                    cas_nom_dossier          cas_zone_nom  \
# 0       2            MARIGOT (LE) (972) 1937            Martinique
# 1       3  [AERO MIL] ORANGE (84) 15 06 1951              Vaucluse
# 2       4             BIARRITZ (64)  08 1951  Pyrénées-Atlantiques
# 3       5      PORT-GENTIL (GA 8) 01 06 1952              Ardennes
# 4       6  CRECY-EN-PONTHIEU (80) 21 09 1952                 Somme
#
#   cas_zone_code    cas_zone_type cas_AAAA cas_MM cas_JJ  \
# 0           972  (D) Département     1937
# 1            84  (D) Département     1951      6     15
# 2            64  (D) Département     1951      8
# 3             8  (D) Département     1952      6      1
# 4            80  (D) Département     1952      9     21
#
#                                           cas_resume  \
# 0  Témoignage récent (11/09/1979) d'une observati...
# 1  Le 15 juin 1951 à 11h30 deux pilotes décollent...
# 2  Témoignage récent (20/03/1975) d'une observati...
# 3  Le 1er juin 1952 à 2h40 du matin, deux personn...
# 4  Témoignage récent (21/11/2010) d'une observati...
#
#                                       cas_resume_web  ... cas_fiabilite_err  \
# 0  Observation du déplacement d'un globe éclairé ...  ...               NaN
# 1  Observations par deux pilotes en vol d'un phén...  ...               NaN
# 2  OBSERVATION DU DÉPLACEMENT SILENCIEUX AVEC CHA...  ...               NaN
# 3  Observations du passage d'un phénomène lumineu...  ...               NaN
# 4  Observation d'un engin circulaire de couleur g...  ...               NaN
#
#    cas_fiabilite_calc  cas_qte_information  cas_qte_information_calc  \
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                 NaN                  NaN                       NaN
# 3                 NaN                  NaN                       NaN
# 4                 NaN                  NaN                       NaN
#
#    cas_consistance  cas_consistance_calc  cas_consistance_calc_err  \
# 0              NaN                  0 28                      0 28
# 1              NaN                  0 78                      0 23
# 2              NaN                  0 28                      0 28
# 3              NaN                  0 78                      0 23
# 4              NaN                  0 28                      0 28
#
#    cas_classification  cas_classification_calc   cas_numEtude
# 0                   C                        C  1937-01-01656
# 1                  D1                       D1  1951-06-00002
# 2                   C                        C  1951-08-00003
# 3                  D1                       D1  1952-06-00004
# 4                   C                        C  1952-09-08193
#
# [5 rows x 35 columns]

# %%
df_temoignages = pd.read_csv('temoignages_pub.csv', sep =';', encoding='iso-8859-1',low_memory=False)
df_temoignages.head()
# Out:
#    id_cas   cas_numEtude  id_temoignage  tem_new tem_chrono  obs_chrono  \
# 0       2  1937-01-01656             31        0        NaN  1937 01 01
# 1       3  1951-06-00002             32        0        NaN  1951 06 01
# 2       3  1951-06-00002             33        0        NaN  1951 06 02
# 3       4  1951-08-00003             34        0        NaN  1951 08 01
# 4       5  1952-06-00004             35        0        NaN  1952 06 01
#
#                         tem_nom_dossier tem_title_nickname tem_title_type  \
# 0             MARIGOT (LE) (972)   1937                NaN            NaN
# 1  [AERO MIL] ORANGE (84) 15 06 1951 T1                NaN            NaN
# 2  [AERO MIL] ORANGE (84) 15 06 1951 T2                NaN            NaN
# 3                BIARRITZ (64)  08 1951                NaN            NaN
# 4         PORT-GENTIL (GA 8) 01 06 1952                NaN            NaN
#
#   tem_resume  ...  obs_deg_parcouru  obs_nb_PAN obs_nb_PAN_lib  obs_formation  \
# 0        NaN  ...               NaN         1.0        Un seul            NaN
# 1        NaN  ...               NaN         1.0        Un seul            NaN
# 2        NaN  ...               NaN         1.0        Un seul            NaN
# 3        NaN  ...               NaN         1.0        Un seul            NaN
# 4        NaN  ...               NaN         1.0        Un seul            NaN
#
#   obs_formation_type obs_caracteristiques obs_continuite  \
# 0                NaN                  NaN            NaN
# 1                NaN                  NaN            NaN
# 2                NaN                  NaN            NaN
# 3                NaN                  NaN            NaN
# 4                NaN                  NaN            NaN
#
#       obs_continuite_type obs_PAN_calculs obs_envt_equipements_actifs
# 0  Observation en continu             NaN                         NaN
# 1                     NaN             NaN                         NaN
# 2                     NaN             NaN                         NaN
# 3  Observation en continu             NaN                         NaN
# 4  Observation en continu             NaN                         NaN
#
# [5 rows x 263 columns]

# %% [markdown]
# #### Traitement des données nulles

# %%
## pourcentage de valeurs nulles pour chaque colonne
NULL = 100 * (df_cas.shape[0] - df_cas.describe().T['count']) / df_cas.shape[0];
NULL
# Out:
# id_cas                        0.000000
# cas_temoignages_nb           25.867052
# cas_temoins_nb               93.713873
# cas_temoins_nb_approx       100.000000
# cas_nb_PAN                   94.869942
# cas_nb_PAN_approx           100.000000
# cas_MinCercleInscrit_Lat    100.000000
# cas_MinCercleInscrit_Lng    100.000000
# cas_MinCercleInscrit_Err    100.000000
# cas_etrangete_err           100.000000
# cas_fiabilite_err           100.000000
# Name: count, dtype: float64

# %%
## pourcentage de valeurs nulles pour chaque colonne
NULL = 100 * (df_temoignages.shape[0] - df_temoignages.describe().T['count']) / df_temoignages.shape[0];
NULL
# Out:
# id_cas                          0.000000
# id_temoignage                   0.000000
# tem_new                         0.000000
# tem_Gi                         80.507842
# tem_Ti                          3.360717
# tem_TComi                      45.313667
# tem_adr_CP                     59.671397
# tem_xp_aero_niveau             99.645258
# tem_xp_astro_niveau            99.719940
# tem_xp_topo_niveau             99.719940
# tem_xp_UFO_niveau              99.626587
# tem_photos_retouchees         100.000000
# tem_plans                     100.000000
# tem_croquis                   100.000000
# tem_GD                          6.777446
# tem_A                          98.879761
# tem_PVi                        15.795370
# tem_numSEPRA                    0.000000
# id_temoignage_old              74.215833
# id_observation                  0.000000
# obs_nb                          0.000000
# obs_commune_or_trajet           0.000000
# obs_tem_dep                    99.122479
# obs_MM                          0.429425
# obs_heure_deb                 100.000000
# obs_heure_fin                 100.000000
# obs_heure_delta                 0.000000
# obs_heure_tranche_horaire     100.000000
# obs_heure_approx               99.495892
# obs_1_adr_CP                    0.728155
# obs_1_adr_CP_2                 96.751307
# obs_1_alt                      49.253174
# obs_conditions_apparition      21.769978
# obs_conditions_emotions       100.000000
# obs_2_alt                     100.000000
# obs_2_PAN_altitude            100.000000
# obs_2_distance_abs            100.000000
# obs_3_adr_bat                 100.000000
# obs_3_adr_num_voie             99.981329
# obs_3_adr_type_voie           100.000000
# obs_3_adr_CP                   97.890217
# obs_3_adr_pays                100.000000
# obs_3_alt                      99.943988
# obs_conditions_disparition     24.626587
# obs_3_distance_abs            100.000000
# obs_3_PAN_altitude            100.000000
# obs_nb_PAN                     34.596714
# obs_formation                 100.000000
# obs_formation_type            100.000000
# obs_PAN_calculs               100.000000
# Name: count, dtype: float64

# %%
# suppresion des colonnes inutiles
df_cas.drop(["cas_temoins_nb_approx", "cas_nb_PAN", "cas_nb_PAN_approx", "cas_MinCercleInscrit_Lat", "cas_MinCercleInscrit_Lng", "cas_MinCercleInscrit_Err", "cas_etrangete_err", "cas_fiabilite_err"], axis = 1, inplace = True) 
# display 
df_cas
# Out:
#       id_cas                    cas_nom_dossier          cas_zone_nom  \
# 0          2            MARIGOT (LE) (972) 1937            Martinique
# 1          3  [AERO MIL] ORANGE (84) 15 06 1951              Vaucluse
# 2          4             BIARRITZ (64)  08 1951  Pyrénées-Atlantiques
# 3          5      PORT-GENTIL (GA 8) 01 06 1952              Ardennes
# 4          6  CRECY-EN-PONTHIEU (80) 21 09 1952                 Somme
# ...      ...                                ...                   ...
# 2763    4783             PIGNAN (34) 07 07 2018               Hérault
# 2764    4799          MARSEILLE (13) 07 08 2018      Bouches-du-Rhône
# 2765    4840          FOA (LA) (988) 05 03 1984    Nouvelle-Calédonie
# 2766    4842            FOA (LA) (988)  03 1984    Nouvelle-Calédonie
# 2767    4851          MARTIGUES (13) 02 12 2018      Bouches-du-Rhône
#
#      cas_zone_code    cas_zone_type cas_AAAA cas_MM cas_JJ  \
# 0              972  (D) Département     1937
# 1               84  (D) Département     1951      6     15
# 2               64  (D) Département     1951      8
# 3                8  (D) Département     1952      6      1
# 4               80  (D) Département     1952      9     21
# ...            ...              ...      ...    ...    ...
# 2763            34  (D) Département     2018      7      7
# 2764            13  (D) Département     2018      8      7
# 2765           988  (D) Département     1984      3      5
# 2766           988  (D) Département     1984      3
# 2767            13  (D) Département     2018     12      2
#
#                                              cas_resume  \
# 0     Témoignage récent (11/09/1979) d'une observati...
# 1     Le 15 juin 1951 à 11h30 deux pilotes décollent...
# 2     Témoignage récent (20/03/1975) d'une observati...
# 3     Le 1er juin 1952 à 2h40 du matin, deux personn...
# 4     Témoignage récent (21/11/2010) d'une observati...
# ...                                                 ...
# 2763  Le 07 juillet 2018 vers 22h45 un témoin, dans ...
# 2764  Dans la nuit du 06 au 07 août 2018 vers 01h12 ...
# 2765  Le GEIPAN continue à publier l'ensemble de ses...
# 2766  Le GEIPAN continue à publier l'ensemble de ses...
# 2767  Le dimanche 02 décembre 2018 aux alentours de ...
#
#                                          cas_resume_web  ... cas_fiabilite  \
# 0     Observation du déplacement d'un globe éclairé ...  ...           NaN
# 1     Observations par deux pilotes en vol d'un phén...  ...           NaN
# 2     OBSERVATION DU DÉPLACEMENT SILENCIEUX AVEC CHA...  ...           NaN
# 3     Observations du passage d'un phénomène lumineu...  ...           NaN
# 4     Observation d'un engin circulaire de couleur g...  ...           NaN
# ...                                                 ...  ...           ...
# 2763  Observation du passage silencieux Nord-Sud d'u...  ...           NaN
# 2764  Observation à l'il nu puis aux jumelles d'un p...  ...           NaN
# 2765  Très longues observations (2 heures) par deux ...  ...           NaN
# 2766  Observation à trois reprises d'une large bande...  ...           NaN
# 2767  Observation par un automobiliste de la présenc...  ...           NaN
#
#       cas_fiabilite_calc  cas_qte_information cas_qte_information_calc  \
# 0                    NaN                  NaN                      NaN
# 1                    NaN                  NaN                      NaN
# 2                    NaN                  NaN                      NaN
# 3                    NaN                  NaN                      NaN
# 4                    NaN                  NaN                      NaN
# ...                  ...                  ...                      ...
# 2763                0 70                  NaN                     0 60
# 2764                0 70                  NaN                     0 80
# 2765                0 70                  NaN                     0 70
# 2766                0 50                  NaN                     0 40
# 2767                0 70                  NaN                     0 70
#
#      cas_consistance cas_consistance_calc cas_consistance_calc_err  \
# 0                NaN                 0 28                     0 28
# 1                NaN                 0 78                     0 23
# 2                NaN                 0 28                     0 28
# 3                NaN                 0 78                     0 23
# 4                NaN                 0 28                     0 28
# ...              ...                  ...                      ...
# 2763             NaN                 0 45                     0 00
# 2764             NaN                 0 60                     0 00
# 2765             NaN                 0 50                     0 00
# 2766             NaN                 0 20                     0 00
# 2767             NaN                 0 50                     0 00
#
#      cas_classification cas_classification_calc   cas_numEtude
# 0                     C                       C  1937-01-01656
# 1                    D1                      D1  1951-06-00002
# 2                     C                       C  1951-08-00003
# 3                    D1                      D1  1952-06-00004
# 4                     C                       C  1952-09-08193
# ...                 ...                     ...            ...
# 2763                  B                       B  2018-07-50605
# 2764                  A                       A  2018-08-50619
# 2765                  A                       A  1984-03-50655
# 2766                  C                       C  1984-03-50657
# 2767                  B                       B  2018-12-50667
#
# [2768 rows x 27 columns]

# %%
# suppresion des colonnes inutiles
df_temoignages.drop(["tem_xp_aero_niveau", "tem_xp_topo_niveau", "tem_xp_UFO_niveau", "tem_photos_retouchees", "tem_plans", "tem_croquis", "obs_tem_dep", "obs_heure_deb",
 "obs_heure_fin", "obs_heure_tranche_horaire", "obs_heure_approx", "obs_conditions_emotions", "obs_2_alt", "obs_2_PAN_altitude", "obs_2_distance_abs", "obs_3_adr_bat", 
"obs_3_adr_num_voie", "obs_3_adr_type_voie", "obs_3_adr_pays", "obs_3_alt", "obs_3_distance_abs" , "obs_3_PAN_altitude", "obs_formation", "obs_formation_type", "obs_PAN_calculs"], axis = 1, inplace = True) 
# display 
df_temoignages
# Out:
#       id_cas   cas_numEtude  id_temoignage  tem_new  tem_chrono  obs_chrono  \
# 0          2  1937-01-01656             31        0         NaN  1937 01 01
# 1          3  1951-06-00002             32        0         NaN  1951 06 01
# 2          3  1951-06-00002             33        0         NaN  1951 06 02
# 3          4  1951-08-00003             34        0         NaN  1951 08 01
# 4          5  1952-06-00004             35        0         NaN  1952 06 01
# ...      ...            ...            ...      ...         ...         ...
# 5351    4841  1984-03-50656           4163        0         NaN  1984 03 04
# 5352    4841  1984-03-50656           4164        0         NaN  1984 03 05
# 5353    4842  1984-03-50657           4165        0         NaN  1984 03 06
# 5354    4842  1984-03-50657           4166        0         NaN  1984 03 07
# 5355    4851  2018-12-50667           9580        0  2018 12 01         NaN
#
#                            tem_nom_dossier tem_title_nickname tem_title_type  \
# 0                MARIGOT (LE) (972)   1937                NaN            NaN
# 1     [AERO MIL] ORANGE (84) 15 06 1951 T1                NaN            NaN
# 2     [AERO MIL] ORANGE (84) 15 06 1951 T2                NaN            NaN
# 3                   BIARRITZ (64)  08 1951                NaN            NaN
# 4            PORT-GENTIL (GA 8) 01 06 1952                NaN            NaN
# ...                                    ...                ...            ...
# 5351          FOA (LA) (988) 02 03 1984 T1                NaN            NaN
# 5352          FOA (LA) (988) 02 03 1984 T2                NaN            NaN
# 5353            FOA (LA) (988)  03 1984 T1                NaN            NaN
# 5354           FOA (LA) (988)  03 1984 Ti2                NaN            NaN
# 5355             MARTIGUES (13) 02 12 2018                NaN            NaN
#
#                                              tem_resume  ...  \
# 0                                                   NaN  ...
# 1                                                   NaN  ...
# 2                                                   NaN  ...
# 3                                                   NaN  ...
# 4                                                   NaN  ...
# ...                                                 ...  ...
# 5351  Domicilié au quartier Méaré le témoin voit dep...  ...
# 5352   vu apparaître une boule de feu dans le ciel a...  ...
# 5353  Devant son domicile à LA FOA il voit dans le c...  ...
# 5354  Prévenu le lendemain par son voisin qui habite...  ...
# 5355  Le témoin circule au volant de sa voiture sur ...  ...
#
#       obs_3_PAN_pos_approx  obs_incli obs_incli_lib  \
# 0                      NaN        NaN           NaN
# 1                      NaN        NaN           NaN
# 2                      NaN        NaN           NaN
# 3                      NaN        NaN           NaN
# 4                      NaN        NaN           NaN
# ...                    ...        ...           ...
# 5351                   NaN        NaN           NaN
# 5352                   NaN        NaN           NaN
# 5353                   NaN        NaN           NaN
# 5354                   NaN        NaN           NaN
# 5355                   NaN        NaN           NaN
#
#                                        obs_deg_parcouru obs_nb_PAN  \
# 0                                                   NaN        1.0
# 1                                                   NaN        1.0
# 2                                                   NaN        1.0
# 3                                                   NaN        1.0
# 4                                                   NaN        1.0
# ...                                                 ...        ...
# 5351                                                 NP        1.0
# 5352                                                 NP        1.0
# 5353                                                 NP        NaN
# 5354                                                 NP        NaN
# 5355  STATIQUE puis Oblique et prise d'altitude pour...        2.0
#
#                                          obs_nb_PAN_lib obs_caracteristiques  \
# 0                                               Un seul                  NaN
# 1                                               Un seul                  NaN
# 2                                               Un seul                  NaN
# 3                                               Un seul                  NaN
# 4                                               Un seul                  NaN
# ...                                                 ...                  ...
# 5351                                                  1                  NaN
# 5352                                                  1                  NaN
# 5353                            1 (vu à trois reprises)                  NaN
# 5354                                                 NP                  NaN
# 5355  2 Objets bien distincts l'un des deux était él...                  NaN
#
#                                   obs_continuite      obs_continuite_type  \
# 0                                            NaN   Observation en continu
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN   Observation en continu
# 4                                            NaN   Observation en continu
# ...                                          ...                      ...
# 5351                                         NaN   Observation en continu
# 5352                                         NaN   Observation en continu
# 5353                                         NaN   Observation en continu
# 5354                                         NaN              Non précisé
# 5355  A la découverte du phénomène je conduisais  Observation discontinue
#
#                             obs_envt_equipements_actifs
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5351                                                 NP
# 5352                                                 NP
# 5353                                                 NP
# 5354                                                 NP
# 5355  Dans un premier temps au volant donc phare pas...
#
# [5356 rows x 238 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U21') dtype('<U21') dtype('<U21')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-57897668e411> in <module>
#       2 fileNames = [df_cas,df_temoignages]
#       3 for currentFilename in fileNames:
# ----> 4     filename = currentFilename + '.csv'
#       5     ## Calculating lines to convert
#       6     initialFile= open(filename,"r")
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#    1504
#    1505             assert np.ndim(other) == 0
# -> 1506             return self._combine_const(other, op)
#    1507
#    1508     f.__name__ = op_name
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func)
#    5401     def _combine_const(self, other, func):
#    5402         assert lib.is_scalar(other) or np.ndim(other) == 0
# -> 5403         return ops.dispatch_to_series(self, other, func)
#    5404
#    5405     def combine(self, other, func, fill_value=None, overwrite=True):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     594         raise NotImplementedError(right)
#     595
# --> 596     new_data = expressions.evaluate(column_op, str_rep, left, right)
#     597
#     598     result = left._constructor(new_data, index=left.index, copy=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     219     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#     223
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     125
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#     129     return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in column_op(a, b)
#     568
#     569         def column_op(a, b):
# --> 570             return {i: func(a.iloc[:, i], b) for i in range(len(a.columns))}
#     571
#     572     elif isinstance(right, ABCDataFrame):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in <dictcomp>(.0)
#     568
#     569         def column_op(a, b):
# --> 570             return {i: func(a.iloc[:, i], b) for i in range(len(a.columns))}
#     571
#     572     elif isinstance(right, ABCDataFrame):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in masked_arith_op(x, y, op)
#     462         if mask.any():
#     463             with np.errstate(all="ignore"):
# --> 464                 result[mask] = op(xrav[mask], y)
#     465
#     466     result, changed = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U21') dtype('<U21') dtype('<U21')
